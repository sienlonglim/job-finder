# %%
# The following was obtained from stackoverflow

# from selenium import webdriver
# from selenium.webdriver.common.by import By
# from selenium.webdriver.common.keys import Keys
# from selenium.webdriver.support.ui import Select
# from selenium.webdriver.support.ui import WebDriverWait
# from selenium.common.exceptions import TimeoutException
# from selenium.webdriver.support import expected_conditions as EC
# from selenium.common.exceptions import NoSuchElementException
# from selenium.common.exceptions import NoAlertPresentException
# import sys

# import unittest, time, re

# class Sel(unittest.TestCase):
#     def setUp(self):
#         self.driver = webdriver.Firefox()
#         self.driver.implicitly_wait(30)
#         self.base_url = "https://twitter.com"
#         self.verificationErrors = []
#         self.accept_next_alert = True
        
#     def test_sel(self):
#         driver = self.driver
#         delay = 3
#         driver.get(self.base_url + "/search?q=stckoverflow&src=typd")
#         driver.find_element_by_link_text("All").click()
#         for i in range(1,100):
#             self.driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
#             time.sleep(4)
#         html_source = driver.page_source
#         data = html_source.encode('utf-8')


# if __name__ == "__main__":
#     unittest.main()

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support import expected_conditions as EC
from bs4 import BeautifulSoup
import time, re

keyword = 'data analyst'
title = re.sub(' ', '%20', keyword.lower()) # This is used for building url
keyword = re.sub(' ', '-', keyword.lower())

# Not using context manager, because we may need to close and restart if running into an authentication wall
driver = webdriver.Chrome()
driver.implicitly_wait(30)
driver.get(f"https://www.linkedin.com/jobs/search/?distance=25&geoId=102454443&keywords={title}&location=Singapore&start=0")
html_source = driver.page_source
soup = BeautifulSoup(html_source,'html.parser')
retry_count = 0
# Sometimes we will run into an authentication wall, retry again until successful
while retry_count < 5 and "Sign Up | LinkedIn" in soup.find('title').text:
    print(f"\tRan into AuthWall, trying again in 5 secs...")
    driver.quit()
    time.sleep(5)
    driver = webdriver.Chrome()
    driver.get(f"https://www.linkedin.com/jobs/search/?distance=25&geoId=102454443&keywords={title}&location=Singapore&start=0")
    html_source = driver.page_source
    soup = BeautifulSoup(html_source,'html.parser')
    retry_count +=1

for i in range(1,100):
    time.sleep(2)
    webdriver.ActionChains(driver).scroll_by_amount(0, -10).perform() # Need to scroll up a little to trigger infinite scroll
    time.sleep(2)
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    try: # Occasionally there will be a click to see more button appear, need to click on it, sometimes two clicks are needed
        element = WebDriverWait(driver, 1).until(
            EC.presence_of_element_located(
                (By.XPATH,'//*[@id="main-content"]/section[2]/button')))
        if element:
            driver.execute_script("arguments[0].click()", element)
            time.sleep(0.5)
            driver.execute_script("arguments[0].click()", element)
    except Exception as e:
        print(e)
    
html_source = driver.page_source
driver.quit()
# Out:
# 	Ran into AuthWall, trying again in 5 secs...

# %%
def custom_selector(tag):
        '''
        Helper function used to identify a href tag with belongs to the job link
        Inputs:
            soup tag
        Returns soup tag
        '''
        return tag.name == "a" and tag.has_attr("href") and keyword in tag.get('href')

data = {}
soup = BeautifulSoup(html_source,'html.parser')
tags = soup.find_all(custom_selector)

# Get the link and jobid for each listed job
for tag in tags:
    link = tag.get('href')
    link = link.split('?')[0] # Tidy up the link to remove the trackingid
    if 'login' not in link:
        data.setdefault(link, 0)
        data[link] += 1
data
# Out:
# {'https://sg.linkedin.com/jobs/view/data-analyst-at-capgemini-3764392364': 1,
#  'https://sg.linkedin.com/jobs/view/data-analyst-at-starbucks-coffee-singapore-3775365168': 1,
#  'https://sg.linkedin.com/jobs/view/junior-data-analyst-business-intelligence-regional-operations-at-shopee-3727428385': 1,
#  'https://sg.linkedin.com/jobs/view/data-analyst-planning-budgeting-sg-warehouse-at-shopee-3783416267': 1,
#  'https://sg.linkedin.com/jobs/view/data-analyst-at-sea-3616637587': 1,
#  'https://sg.linkedin.com/jobs/view/data-analyst-marketing-analytics-regional-brand-growth-marketing-at-shopee-3775405705': 1,
#  'https://sg.linkedin.com/jobs/view/data-analyst-marketplace-product-at-shopee-3721375973': 1,
#  'https://sg.linkedin.com/jobs/view/data-analyst-at-ninja-van-3772981858': 1,
#  'https://sg.linkedin.com/jobs/view/data-analyst-chatbot-customer-service-2024-fresh-graduates-at-shopee-3792429156': 1,
#  'https://sg.linkedin.com/jobs/view/data-analyst-marketplace-product-2024-fresh-graduates-at-shopee-3777454584': 1,
#  'https://sg.linkedin.com/jobs/view/data-analyst-at-allianz-global-investors-3757235292': 1,
#  'https://sg.linkedin.com/jobs/view/data-analyst-sql-snowflake-at-hcltech-3774450037': 1,
#  'https://sg.linkedin.com/jobs/view/data-analyst-singapore-at-yipitdata-3738898017': 1,
#  'https://sg.linkedin.com/jobs/view/data-analyst-business-intelligence-regional-operations-at-shopee-3684120093': 1,
#  'https://sg.linkedin.com/jobs/view/data-analyst-p9837-at-xiaomi-technology-3731038493': 1,
#  'https://sg.linkedin.com/jobs/view/data-analyst-at-zespri-international-3789263548': 1,
#  'https://sg.linkedin.com/jobs/view/data-analyst-shopeepay-at-seamoney-3727820700': 1,
#  'https://sg.linkedin.com/jobs/view/e-commerce-data-analyst-at-tiktok-3747544708': 1,
#  'https://sg.linkedin.com/jobs/view/data-analyst-at-singtel-3790491475': 1,
#  'https://sg.linkedin.com/jobs/view/data-analyst-at-menyala-3779862000': 1,
#  'https://sg.linkedin.com/jobs/view/regional-operations-data-analyst-at-shopee-3616269964': 1,
#  'https://sg.linkedin.com/jobs/view/data-analyst-at-total-ebiz-solutions-3788244015': 1,
#  'https://sg.linkedin.com/jobs/view/data-analyst-at-sistic-singapore-3791685640': 1,
#  'https://sg.linkedin.com/jobs/view/data-analyst-associate-at-pwc-singapore-3772507899': 1,
#  'https://sg.linkedin.com/jobs/view/data-analyst-finance-singapore-at-revolut-3736227202': 1,
#  'https://sg.linkedin.com/jobs/view/finance-data-analyst-at-jpmorgan-chase-co-3773074391': 1,
#  'https://sg.linkedin.com/jobs/view/supply-chain-data-analyst-at-hp-3789282020': 1,
#  'https://sg.linkedin.com/jobs/view/data-analyst-power-bi-analyst-at-microsoft-operations-pte-ltd-3785249512': 1,
#  'https://sg.linkedin.com/jobs/view/data-analyst-at-whitecoat-global-3761384366': 1,
#  'https://sg.linkedin.com/jobs/view/data-analyst-intern-regional-marketing-analytics-regional-brand-growth-marketing-spring-2024-at-shopee-3611204819': 1,
#  'https://sg.linkedin.com/jobs/view/data-analyst-at-arta-finance-3775716634': 1,
#  'https://sg.linkedin.com/jobs/view/data-analyst-python-developer-jr027-at-unison-consulting-3765837868': 1,
#  'https://sg.linkedin.com/jobs/view/shipping-data-analyst-at-triton-ai-pte-ltd-3783626590': 1,
#  'https://sg.linkedin.com/jobs/view/data-analyst-at-intellect-minds-3774458964': 1,
#  'https://sg.linkedin.com/jobs/view/data-analyst-2024-campus-recruitment-at-xiaomi-technology-3736835317': 1,
#  'https://sg.linkedin.com/jobs/view/data-analyst-digital-banking-at-seamoney-3779064039': 1,
#  'https://sg.linkedin.com/jobs/view/senior-data-analyst-at-4e-exchange-3716933612': 1,
#  'https://sg.linkedin.com/jobs/view/data-analyst-at-binance-3778427691': 1,
#  'https://sg.linkedin.com/jobs/view/data-analyst-risk-at-shield-3668248972': 1,
#  'https://sg.linkedin.com/jobs/view/data-analyst-marketing-at-razer-inc-3777043371': 1,
#  'https://sg.linkedin.com/jobs/view/e-commerce-data-analyst-at-chicme-3743191856': 1,
#  'https://sg.linkedin.com/jobs/view/urgent-hiring-for-data-analyst-at-prime-immigration-3792327502': 1,
#  'https://sg.linkedin.com/jobs/view/data-analyst-global-branding-at-hoyoverse-3693534895': 1,
#  'https://sg.linkedin.com/jobs/view/business-analyst-data-analyst-intern-at-glints-3575090531': 1,
#  'https://sg.linkedin.com/jobs/view/data-analyst-for-data-analytics-startup-at-thinkval-3790923638': 1,
#  'https://sg.linkedin.com/jobs/view/senior-data-analyst-at-study-group-3785005424': 1,
#  'https://sg.linkedin.com/jobs/view/senior-data-analyst-at-big-cloud-3780122428': 1,
#  'https://sg.linkedin.com/jobs/view/data-analyst-at-amaris-consulting-3729120053': 1,
#  'https://sg.linkedin.com/jobs/view/senior-business-intelligence-bi-data-analyst-at-dyson-3703618257': 1,
#  'https://sg.linkedin.com/jobs/view/data-analyst-cross-project-at-hoyoverse-3693533935': 1,
#  'https://sg.linkedin.com/jobs/view/data-analyst-honkai-star-rail-at-hoyoverse-3693536674': 1,
#  'https://sg.linkedin.com/jobs/view/regional-marketplace-operations-data-analyst-at-shopee-3725015864': 1,
#  'https://sg.linkedin.com/jobs/view/it-data-analyst-at-cosmostar-singapore-private-limited-3778972020': 1,
#  'https://sg.linkedin.com/jobs/view/data-analyst-healthtech-associate-programme-at-synapxe-3677794345': 1,
#  'https://sg.linkedin.com/jobs/view/data-analyst-e-commerce-user-growth-at-tiktok-3605003219': 1,
#  'https://sg.linkedin.com/jobs/view/data-analyst-at-u3-infotech-pte-ltd-3793991690': 1,
#  'https://sg.linkedin.com/jobs/view/data-analyst-monetization-at-bytedance-3599788524': 1,
#  'https://sg.linkedin.com/jobs/view/data-analyst-etl-at-peoplebank-3773300453': 1,
#  'https://sg.linkedin.com/jobs/view/data-analyst-at-star-information-systems-3783067038': 1,
#  'https://sg.linkedin.com/jobs/view/senior-data-analyst-at-charterhouse-asia-3780053985': 1,
#  'https://sg.linkedin.com/jobs/view/lead-data-analyst-at-dyson-3775345393': 1,
#  'https://sg.linkedin.com/jobs/view/data-analyst-wm-business-analytics-at-bnp-paribas-3791400509': 1,
#  'https://sg.linkedin.com/jobs/view/junior-senior-data-analyst-power-bi-immediate-starter-at-adecco-3744539391': 1,
#  'https://sg.linkedin.com/jobs/view/data-analyst-data-scientist-at-juronghealth-campus-3570084819': 1,
#  'https://sg.linkedin.com/jobs/view/senior-data-analyst-at-study-group-3785622602': 1,
#  'https://sg.linkedin.com/jobs/view/affiliate-data-analyst-at-okx-3748564882': 1,
#  'https://sg.linkedin.com/jobs/view/data-analyst-at-applicantz-3793960626': 1,
#  'https://sg.linkedin.com/jobs/view/regional-political-data-analyst-at-nicoll-curtin-3768749938': 1,
#  'https://sg.linkedin.com/jobs/view/data-analyst-low-voltage-software-automation-at-tesla-3779693552': 1,
#  'https://sg.linkedin.com/jobs/view/data-analyst-at-attribute-data-pte-ltd-3793406045': 1,
#  'https://sg.linkedin.com/jobs/view/data-analyst-rdbms-java-python-powerbi-tableau-denodo-at-maltem-asia-pacific-3780260835': 1,
#  'https://sg.linkedin.com/jobs/view/data-analyst-cybersecurity-at-recruit-now-singapore-pte-ltd-3783795417': 1,
#  'https://sg.linkedin.com/jobs/view/reporting-data-analyst-contractor-at-schroders-3781169330': 1,
#  'https://sg.linkedin.com/jobs/view/senior-data-analyst-power-bi-at-geco-asia-pte-ltd-3783884875': 1,
#  'https://sg.linkedin.com/jobs/view/data-analyst-at-arta-tech-pte-ltd-3780542368': 1,
#  'https://sg.linkedin.com/jobs/view/affiliate-data-analyst-at-okx-3726994524': 1,
#  'https://sg.linkedin.com/jobs/view/researcher-data-analyst-at-persol-singapore-3787861579': 1,
#  'https://sg.linkedin.com/jobs/view/anti-money-laundering-data-analyst-digital-banking-at-seamoney-3750291354': 1,
#  'https://sg.linkedin.com/jobs/view/senior-e-commerce-data-analyst-global-operations-center-sin-at-shein-3763355259': 1,
#  'https://sg.linkedin.com/jobs/view/data-analyst-at-tesla-motors-singapore-holdings-pte-ltd-3785239924': 1,
#  'https://sg.linkedin.com/jobs/view/data-analyst-global-payments-at-bytedance-3650802260': 1,
#  'https://sg.linkedin.com/jobs/view/e-commerce-data-analyst-at-tiktok-3617980804': 1,
#  'https://sg.linkedin.com/jobs/view/data-analyst-byteplus-recommend-at-byteplus-pte-ltd-3774935609': 1,
#  'https://sg.linkedin.com/jobs/view/business-data-analyst-tableau-sql-bank-l-contract-at-manpower-singapore-3788287145': 1,
#  'https://sg.linkedin.com/jobs/view/data-analyst-at-tesla-motors-singapore-private-limited-3780552180': 1,
#  'https://sg.linkedin.com/jobs/view/project-control-engineer-data-analyst-at-agile-talent-3752083944': 1,
#  'https://sg.linkedin.com/jobs/view/data-analyst-payments-fintech-at-page-personnel-3728168751': 1,
#  'https://sg.linkedin.com/jobs/view/data-analyst-genshin-impact-at-hoyoverse-3693533943': 1,
#  'https://sg.linkedin.com/jobs/view/business-data-analyst-at-abbvie-operations-singapore-pte-ltd-3786883030': 1,
#  'https://sg.linkedin.com/jobs/view/senior-data-analyst-at-klook-3779110996': 1,
#  'https://sg.linkedin.com/jobs/view/executive-senior-executive-data-analyst-and-accelerated-digitalisation-at-dhl-supply-chain-3772506851': 1,
#  'https://sg.linkedin.com/jobs/view/it-data-analyst-at-cosmostar-singapore-private-limited-3779596192': 1,
#  'https://sg.linkedin.com/jobs/view/cybersecurity-data-analyst-%E2%80%93-data-analytics-and-intel-at-imda-3707281660': 1,
#  'https://sg.linkedin.com/jobs/view/data-analyst-avp-level-asset-management-at-bti-executive-search-3768756118': 1,
#  'https://sg.linkedin.com/jobs/view/data-analyst-splunk-at-recruit-now-singapore-pte-ltd-3779048870': 1,
#  'https://sg.linkedin.com/jobs/view/data-analyst-at-habyt-central-pte-ltd-3775163984': 1,
#  'https://sg.linkedin.com/jobs/view/data-analyst-at-exasoft-pte-ltd-3777119402': 1,
#  'https://sg.linkedin.com/jobs/view/risk-data-analyst-seamoney-credit-at-seamoney-3611209108': 1,
#  'https://sg.linkedin.com/jobs/view/data-analyst-byteplus-recommend-at-byteplus-pte-ltd-3774939289': 1,
#  'https://sg.linkedin.com/jobs/view/data-analyst-manager-at-impact-bpo-services-pte-ltd-3780549395': 1,
#  'https://sg.linkedin.com/jobs/view/procurement-data-analyst-at-infineon-technologies-3792016458': 1,
#  'https://sg.linkedin.com/jobs/view/data-analyst-at-technopals-consultants-pte-ltd-3785807304': 1,
#  'https://sg.linkedin.com/jobs/view/senior-data-analyst-honkai-star-rail-at-hoyoverse-3767577724': 1,
#  'https://sg.linkedin.com/jobs/view/data-analyst-1-year-contract-at-whitecrow-research-3587841044': 1,
#  'https://sg.linkedin.com/jobs/view/data-analyst-functional-at-iotalents-pte-ltd-3779974300': 1,
#  'https://sg.linkedin.com/jobs/view/data-analyst-ii-at-federal-express-singapore-pte-ltd-3778417824': 1,
#  'https://sg.linkedin.com/jobs/view/data-analyst-retail-power-bi-sql-at-randstad-singapore-3755379982': 1,
#  'https://sg.linkedin.com/jobs/view/data-analyst-internal-data-metadata-at-technopals-consultants-pte-ltd-3785822378': 1,
#  'https://sg.linkedin.com/jobs/view/data-analyst-video-infrastructure-at-tiktok-3744707212': 1,
#  'https://sg.linkedin.com/jobs/view/real-estate-sr-technical-data-analyst-at-decathlon-singapore-3784058499': 1,
#  'https://sg.linkedin.com/jobs/view/data-analyst-python-at-hyperscal-solutions-pte-ltd-3773628282': 1,
#  'https://sg.linkedin.com/jobs/view/online-data-analyst-singapore-at-telus-international-3785564675': 1,
#  'https://sg.linkedin.com/jobs/view/business-analyst-data-analyst-at-u3-infotech-pte-ltd-3784146710': 1,
#  'https://sg.linkedin.com/jobs/view/data-analyst-at-msi-global-private-limited-3791823979': 1,
#  'https://sg.linkedin.com/jobs/view/data-analyst-bank-contract-at-manpower-singapore-3791523331': 1,
#  'https://sg.linkedin.com/jobs/view/data-analyst-at-kinhong-pte-limited-3774216698': 1,
#  'https://sg.linkedin.com/jobs/view/data-analyst-tech-mnc-sql-up7k%2B-at-adecco-3790092207': 1,
#  'https://sg.linkedin.com/jobs/view/data-analyst-retail-power-bi-sql-at-randstad-singapore-3754743680': 1,
#  'https://sg.linkedin.com/jobs/view/executive-digital-research-technology-data-analyst-at-eaglestar-3777117925': 1,
#  'https://sg.linkedin.com/jobs/view/data-analyst-payments-fintech-at-michael-page-3728131297': 1,
#  'https://sg.linkedin.com/jobs/view/data-analyst-retail-power-bi-sql-at-randstad-singapore-3766544125': 1,
#  'https://sg.linkedin.com/jobs/view/data-analyst-specialist-investor-business-at-yipitdata-3762653937': 1,
#  'https://sg.linkedin.com/jobs/view/data-analyst-business-analyst-retail-sql-excel-tableau-east-at-align-recruitment-pte-ltd-3778133426': 1,
#  'https://sg.linkedin.com/jobs/view/service-data-analyst-at-ud-trucks-singapore-pte-ltd-3786892002': 1,
#  'https://sg.linkedin.com/jobs/view/senior-compliance-data-analyst-ceo-office-at-okx-3755423766': 1,
#  'https://sg.linkedin.com/jobs/view/data-analyst-job-in-singapore-at-cloud-visa-immigration-llp-3786377880': 1,
#  'https://sg.linkedin.com/jobs/view/senior-data-analyst-chatbot-customer-service-at-shopee-3740602110': 1,
#  'https://sg.linkedin.com/jobs/view/senior-data-analyst-at-sembcorp-industries-ltd-3765413984': 1,
#  'https://sg.linkedin.com/jobs/view/senior-data-analyst-at-ascentis-pte-ltd-3793472133': 1,
#  'https://sg.linkedin.com/jobs/view/associate-manager-data-analyst-at-kpmg-singapore-3778897611': 1,
#  'https://sg.linkedin.com/jobs/view/data-analyst-at-technopals-consultants-pte-ltd-3786544158': 1,
#  'https://sg.linkedin.com/jobs/view/data-analyst-data-mapping-sql-at-randstad-singapore-3759166127': 1,
#  'https://sg.linkedin.com/jobs/view/data-analyst-contract-%3D-12-months-at-zenith-infotech-3789653458': 1,
#  'https://sg.linkedin.com/jobs/view/senior-data-analyst-at-propertyguru-group-3736477356': 1,
#  'https://sg.linkedin.com/jobs/view/associate-esg-data-analyst-at-revantage-asia-a-blackstone-portfolio-company-3779912264': 1,
#  'https://sg.linkedin.com/jobs/view/senior-data-analyst-at-binance-3787106350': 1,
#  'https://sg.linkedin.com/jobs/view/data-analyst-at-elliott-moss-consulting-pte-ltd-3775171029': 1,
#  'https://sg.linkedin.com/jobs/view/senior-compliance-data-analyst-ceo-office-at-okx-3706503491': 1,
#  'https://sg.linkedin.com/jobs/view/data-analyst-risk-at-shield-ai-technologies-pte-ltd-3785250334': 1,
#  'https://sg.linkedin.com/jobs/view/online-data-analyst-at-telus-international-3787056313': 1,
#  'https://sg.linkedin.com/jobs/view/data-analyst-monetization-strategy-operations-mso-at-tiktok-3700961545': 1,
#  'https://sg.linkedin.com/jobs/view/senior-data-analyst-at-pan-united-technologies-pte-ltd-3790527215': 1,
#  'https://sg.linkedin.com/jobs/view/director-data-analyst-esg-delivery-at-standard-chartered-bank-3787228517': 1,
#  'https://sg.linkedin.com/jobs/view/data-analyst-at-total-ebiz-solutions-pte-ltd-3785240889': 1,
#  'https://sg.linkedin.com/jobs/view/enterprise-market-data-analyst-at-luxoft-singapore-3782122306': 1,
#  'https://sg.linkedin.com/jobs/view/online-data-analyst-at-telus-international-3787054527': 1,
#  'https://sg.linkedin.com/jobs/view/data-analyst-at-biologic-technik-private-limited-3775174500': 1,
#  'https://sg.linkedin.com/jobs/view/data-analyst-boootcamp-and-project-work-online-%E2%80%93-part-time-%E2%80%93-gain-your-first-hands-on-experience-at-moyyn-3793083925': 1,
#  'https://sg.linkedin.com/jobs/view/data-analyst-data-engineer-sql-python-at-randstad-singapore-3789170378': 1}
